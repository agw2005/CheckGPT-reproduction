# %% [markdown]
# - **Image** : CC-Ubuntu22.04-CUDA
# - **GPU** : Quadro RTX 6000
# - **CPU** : Intel(R) Xeon(R) Gold 6126 CPU @ 2.60GHz (2)
# - **RAM** : 192GiB
# - **Workspace Kernel** : Python 3.10.12 venv

# %%
# %%bash
# pwd
# ls -a
# Out:
# /home/cc/CheckGPT-reproduction
# .
# ..
# .git
# .venv
# artifact_checkgpt
# gitignore
# repro_checkpoint_1.ipynb

# %%
# !sudo add-apt-repository ppa:deadsnakes/ppa -y > /dev/null 2>&1
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu/ jammy main'
# Description:
# This PPA contains more recent Python versions packaged for Ubuntu.
#
# Disclaimer: there's no guarantee of timely updates in case of security problems or other issues. If you want to use them in a security-or-otherwise-critical environment (say, on a production server), you do so at your own risk.
#
# Update Note
# ...
# Please use this repository instead of ppa:fkrull/deadsnakes.
#
# Reporting Issues
# ...
#
# Issues can be reported in the master issue tracker at:
# https://github.com/deadsnakes/issues/issues
#
# Supported Ubuntu and Python Versions
# ...
#
# - Ubuntu 22.04 (jammy) Python3.7 - Python3.9, Python3.11 - Python3.13
# - Ubuntu 24.04 (noble) Python3.7 - Python3.11, Python3.13
# - Note: Python 3.10 (jammy), Python3.12 (noble) are not provided by deadsnakes as upstream ubuntu provides those packages.
#
# Why some packages aren't built:
# ...

# %%
# %%bash
# sudo apt update -yqq
# sudo apt upgrade -yqq
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
# Hit:1 http://nova.clouds.archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://nova.clouds.archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://nova.clouds.archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 113 packages can be upgraded. Run 'apt list --upgradable' to see them.
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# Get another security update through Ubuntu Pro with 'esm-apps' enabled:
#   libyara8
# ...

# %%
# !sudo DEBIAN_FRONTEND=noninteractive apt install python3.9 python3.9-venv unzip -yqq
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib mailcap mime-support
#   python3.9-distutils python3.9-lib2to3 python3.9-minimal
# Suggested packages:
#   binfmt-support zip
# The following NEW packages will be installed:
#   libpython3.9-minimal libpython3.9-stdlib mailcap mime-support python3.9
#   python3.9-distutils python3.9-lib2to3 python3.9-minimal python3.9-venv unzip
# 0 upgraded, 10 newly installed, 0 to remove and 0 not upgraded.
# Need to get 8526 kB of archives.
# After this operation, 24.0 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3696 B]
# ...

# %%
# !mkdir artifact_checkgpt

# %%
# !python3.9 -m venv ./artifact_checkgpt/.venv

# %%
# %%bash
# wget https://zenodo.org/records/11215222/files/CheckGPT.zip?download=1 -O ./artifact_checkgpt/CheckGPT.zip -nv
# wget https://zenodo.org/records/11215222/files/CheckGPT_presaved_files.zip?download=1 -O ./artifact_checkgpt/CheckGPT_presaved_files.zip -nv
# wget https://zenodo.org/records/11215222/files/CS.zip?download=1 -O ./artifact_checkgpt/CS.zip -nv
# wget https://zenodo.org/records/11215222/files/PHX.zip?download=1 -O ./artifact_checkgpt/PHX.zip -nv
# wget https://zenodo.org/records/11215222/files/HSS.zip?download=1 -O ./artifact_checkgpt/HSS.zip -nv
# wget https://zenodo.org/records/11215222/files/GPABenchmark.zip?download=1 -O ./artifact_checkgpt/GPABenchmark.zip -nv
# wget https://zenodo.org/records/11215222/files/scripts.zip?download=1 -O ./artifact_checkgpt/scripts.zip -nv
# wget https://zenodo.org/records/11215222/files/README.md?download=1 -O ./artifact_checkgpt/README.md -nv
# wget https://zenodo.org/records/11215222/files/requirements.txt?download=1 -O ./artifact_checkgpt/requirements.txt -nv
# Out:
# --2025-12-26 05:12:24--  https://zenodo.org/records/11215222/files/CheckGPT.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.75, 188.185.43.153, 137.138.52.235, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19028 (19K) [application/octet-stream]
# Saving to: ‘./artifact_checkgpt/CheckGPT.zip’
#
#      0K .......... ........                                   100% 54.2K=0.3s
#
# 2025-12-26 05:12:25 (54.2 KB/s) - ‘./artifact_checkgpt/CheckGPT.zip’ saved [19028/19028]
#
# --2025-12-26 05:12:25--  https://zenodo.org/records/11215222/files/CheckGPT_presaved_files.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.75, 137.138.52.235, 188.185.43.153, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 731404045 (698M) [application/octet-stream]
# ...

# %%
# %%bash
# unzip ./artifact_checkgpt/CheckGPT.zip -d ./artifact_checkgpt/
# unzip ./artifact_checkgpt/CheckGPT_presaved_files.zip -d ./artifact_checkgpt/
# mkdir ./artifact_checkgpt/GPABench2/
# unzip ./artifact_checkgpt/CS.zip -d ./artifact_checkgpt/GPABench2/
# unzip ./artifact_checkgpt/PHX.zip -d ./artifact_checkgpt/GPABench2/
# unzip ./artifact_checkgpt/HSS.zip -d ./artifact_checkgpt/GPABench2/
# unzip ./artifact_checkgpt/GPABenchmark.zip -d ./artifact_checkgpt/
# unzip ./artifact_checkgpt/scripts.zip -d ./artifact_checkgpt/CheckGPT/
# Out:
# Archive:  ./artifact_checkgpt/CheckGPT.zip
#    creating: ./artifact_checkgpt/CheckGPT/
#   inflating: ./artifact_checkgpt/__MACOSX/._CheckGPT
#   inflating: ./artifact_checkgpt/CheckGPT/dnn.py
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/._dnn.py
#    creating: ./artifact_checkgpt/CheckGPT/embeddings/
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/._embeddings
#   inflating: ./artifact_checkgpt/CheckGPT/.DS_Store
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/._.DS_Store
#   inflating: ./artifact_checkgpt/CheckGPT/run_input.py
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/._run_input.py
#   inflating: ./artifact_checkgpt/CheckGPT/features.py
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/._features.py
#    creating: ./artifact_checkgpt/CheckGPT/__pycache__/
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/.___pycache__
#   inflating: ./artifact_checkgpt/CheckGPT/logger.py
#   inflating: ./artifact_checkgpt/__MACOSX/CheckGPT/._logger.py
# ...

# %%
# %%bash
# rm ./artifact_checkgpt/CheckGPT.zip
# rm ./artifact_checkgpt/CheckGPT_presaved_files.zip
# rm ./artifact_checkgpt/CS.zip
# rm ./artifact_checkgpt/PHX.zip
# rm ./artifact_checkgpt/HSS.zip
# rm ./artifact_checkgpt/GPABenchmark.zip
# rm ./artifact_checkgpt/scripts.zip

# %%
# %%bash
# ls -a ./artifact_checkgpt/
# ls -a ./artifact_checkgpt/CheckGPT/
# ls -a ./artifact_checkgpt/CheckGPT/scripts
# ls -a ./artifact_checkgpt/CheckGPT_presaved_files
# ls -a ./artifact_checkgpt/GPABench2/
# ls -a ./artifact_checkgpt/GPABench2/CS/
# ls -a ./artifact_checkgpt/GPABench2/PHX/
# ls -a ./artifact_checkgpt/GPABench2/HSS/
# ls -a ./artifact_checkgpt/GPABenchmark/
# Out:
# .
# ..
# .venv
# CheckGPT
# CheckGPT_presaved_files
# GPABench2
# GPABenchmark
# README.md
# __MACOSX
# requirements.txt
# .
# ..
# .DS_Store
# __MACOSX
# __pycache__
# dnn.py
# embeddings
# exp
# features.py
# logger.py
# model.py
# run_input.py
# scripts
# validate_text.py
# .
# ..
# Sec5_10.sh
# Sec5_2_fromscratch.sh
# Sec5_2_smalltest.sh
# Sec5_3_transferability.sh
# Sec5_3_unified_fromscratch.sh
# Sec5_3_unified_smalltest.sh
# Sec5_4.sh
# Sec5_6.sh
# Sec5_7.sh
# features_GPABench2_small.sh
# features_GPABench2_whole.sh
# .
# ..
# .DS_Store
# Additional_data
# Pretrained_models
# saved_experiments
# .
# ..
# CS
# HSS
# PHX
# __MACOSX
# .
# ..
# gpt_task1_prompt1.json
# gpt_task1_prompt2.json
# gpt_task1_prompt3.json
# gpt_task1_prompt4.json
# gpt_task2_prompt1.json
# gpt_task2_prompt2.json
# gpt_task2_prompt3.json
# gpt_task2_prompt4.json
# gpt_task3_prompt1.json
# gpt_task3_prompt2.json
# gpt_task3_prompt3.json
# gpt_task3_prompt4.json
# ground.json
# .
# ..
# ...

# %%
# %%bash
# source ./artifact_checkgpt/.venv/bin/activate
# pip install -r ./artifact_checkgpt/requirements.txt -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
